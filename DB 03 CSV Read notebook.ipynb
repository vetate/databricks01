# %% [markdown]
# # Exploring DBFS

# %%
dbutils.fs.ls(".")
# Out:
# [FileInfo(path='dbfs:/FileStore/', name='FileStore/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/Filestore', name='Filestore', size=687165, modificationTime=1706264087000),
#  FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-results/', name='databricks-results/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/dbfs/', name='dbfs/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/ileStore/', name='ileStore/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/new folder/', name='new folder/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/user/', name='user/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/vetate/', name='vetate/', size=0, modificationTime=0)]

# %%
display(dbutils.fs.ls("."))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/Filestore</td><td>Filestore</td><td>687165</td><td>1706264087000</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/dbfs/</td><td>dbfs/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/ileStore/</td><td>ileStore/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/new folder/</td><td>new folder/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/vetate/</td><td>vetate/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
dbutils.fs.ls("/FileStore/tables/")
# Out:
# [FileInfo(path='dbfs:/FileStore/tables/kaggle/', name='kaggle/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/kaggle-1.json', name='kaggle-1.json', size=68, modificationTime=1704393473000),
#  FileInfo(path='dbfs:/FileStore/tables/kaggle.json', name='kaggle.json', size=68, modificationTime=1704393412000),
#  FileInfo(path='dbfs:/FileStore/tables/loan-1.csv', name='loan-1.csv', size=42730, modificationTime=1705179994000),
#  FileInfo(path='dbfs:/FileStore/tables/loan.csv', name='loan.csv', size=42730, modificationTime=1704313898000),
#  FileInfo(path='dbfs:/FileStore/tables/loan_analysiss/', name='loan_analysiss/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/movie_statistic_dataset.csv', name='movie_statistic_dataset.csv', size=705338, modificationTime=1706276590000)]

# %%
# %pip install pandas
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /databricks/python3/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
# %fs rm -r dbfs:/ileStore
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res6: Boolean = true
# </div>

# %%
dbutils.fs.ls("/FileStore/tables/")
# Out:
# [FileInfo(path='dbfs:/FileStore/tables/kaggle/', name='kaggle/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/kaggle-1.json', name='kaggle-1.json', size=68, modificationTime=1704393473000),
#  FileInfo(path='dbfs:/FileStore/tables/kaggle.json', name='kaggle.json', size=68, modificationTime=1704393412000),
#  FileInfo(path='dbfs:/FileStore/tables/loan-1.csv', name='loan-1.csv', size=42730, modificationTime=1705179994000),
#  FileInfo(path='dbfs:/FileStore/tables/loan.csv', name='loan.csv', size=42730, modificationTime=1704313898000),
#  FileInfo(path='dbfs:/FileStore/tables/loan_analysiss/', name='loan_analysiss/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/movie_statistic_dataset-1.csv', name='movie_statistic_dataset-1.csv', size=705338, modificationTime=1706317785000),
#  FileInfo(path='dbfs:/FileStore/tables/movie_statistic_dataset.csv', name='movie_statistic_dataset.csv', size=705338, modificationTime=1706276590000)]

# %% [markdown]
# ## Read CSV - SPark

# %%
# File location and type
file_location = "/FileStore/tables/movie_statistic_dataset.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movie_title</th><th>production_date</th><th>genres</th><th>runtime_minutes</th><th>director_name</th><th>director_professions</th><th>director_birthYear</th><th>director_deathYear</th><th>movie_averageRating</th><th>movie_numerOfVotes</th><th>approval_Index</th><th>Production budget $</th><th>Domestic gross $</th><th>Worldwide gross $</th></tr></thead><tbody><tr><td>Avatar: The Way of Water</td><td>2022-12-09</td><td>Action,Adventure,Fantasy</td><td>192.0</td><td>James Cameron</td><td>writer,producer,director</td><td>1954</td><td>alive</td><td>7.8</td><td>277543.0</td><td>7.061100943995044</td><td>460000000</td><td>667830256</td><td>2265935552</td></tr><tr><td>Avengers: Endgame</td><td>2019-04-23</td><td>Action,Adventure,Drama</td